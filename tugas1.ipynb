# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

df = pd.read_csv('bank_sliced.csv')
df.head()
# Out:
#   TransactionID CustomerID CustomerDOB CustGender CustLocation  \
# 0        T20002   C3511547     18/4/98          F        DELHI
# 1        T20003   C1340791     29/9/87          F     KOTTAYAM
# 2        T20004   C4726327    15/10/91          F         TONK
# 3        T20005   C3612791     17/4/72          F       MUMBAI
# 4        T20006   C3935459    12/11/86          F        NOIDA
#
#    CustAccountBalance TransactionDate  TransactionTime  \
# 0             7267.76         23/9/16           193515
# 1             4971.10         23/9/16           193518
# 2                4.36         23/9/16           193520
# 3            83461.73         23/9/16           192618
# 4             4184.27         23/9/16           194556
#
#    TransactionAmount (INR)
# 0                   100.00
# 1                   251.00
# 2                   200.00
# 3                   975.04
# 4                    58.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   TransactionID            5000 non-null   object
#  1   CustomerID               5000 non-null   object
#  2   CustomerDOB              4969 non-null   object
#  3   CustGender               4992 non-null   object
#  4   CustLocation             5000 non-null   object
#  5   CustAccountBalance       4998 non-null   float64
#  6   TransactionDate          5000 non-null   object
#  7   TransactionTime          5000 non-null   int64
#  8   TransactionAmount (INR)  5000 non-null   float64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 351.7+ KB

# %%
df.describe()
# Out:
#        CustAccountBalance  TransactionTime  TransactionAmount (INR)
# count        4.998000e+03      5000.000000              5000.000000
# mean         1.238004e+05    165805.047800              1538.065068
# std          5.816404e+05     39290.942032              5522.937391
# min          0.000000e+00        10.000000                 0.000000
# 25%          5.353800e+03    134312.500000               165.000000
# 50%          1.935189e+04    175404.500000               423.000000
# 75%          6.371231e+04    195002.750000              1148.250000
# max          1.725078e+07    232447.000000            170000.000000

# %%
df.isna().sum()
# Out:
# TransactionID               0
# CustomerID                  0
# CustomerDOB                31
# CustGender                  8
# CustLocation                0
# CustAccountBalance          2
# TransactionDate             0
# TransactionTime             0
# TransactionAmount (INR)     0
# dtype: int64

# %%
# Display Null Column Data
df_DOB_null = pd.isnull(df['CustomerDOB'])
# df_Gender_null = pd.isnull(df['CustGender'])
df[df_DOB_null]
# Out:
#      TransactionID CustomerID CustomerDOB CustGender  \
# 170         T20172   C1539187         NaN          M
# 345         T20347   C4621849         NaN          M
# 351         T20353   C7618857         NaN          M
# 470         T20472   C7030841         NaN          M
# 617         T20619   C4227151         NaN          M
# 1131        T21133   C4633064         NaN          M
# 1220        T21222   C5839175         NaN          M
# 1291        T21293   C1312939         NaN          F
# 1626        T21628   C6521427         NaN          F
# 1733        T21735   C3239157         NaN          M
# 1801        T21803   C1711244         NaN          M
# 2420        T22422   C4512392         NaN          M
# 2516        T22518   C8812172         NaN          M
# 2583        T22585   C3439158         NaN          M
# 2945        T22947   C8610544         NaN          M
# 3054        T23056   C8310551         NaN          F
# 3232        T23234   C8533346         NaN          M
# 3395        T23397   C4626156         NaN          M
# 3608        T23610   C4740746         NaN          M
# 3811        T23813   C8233961         NaN          M
# 3832        T23834   C7038518         NaN          F
# 3937        T23939   C1933062         NaN          M
# 3976        T23978   C6122389         NaN        NaN
# 4072        T24074   C3714164         NaN          M
# 4536        T24538   C7128349         NaN          M
# 4602        T24604   C7738788         NaN          M
# 4636        T24638   C5419313         NaN          M
# 4806        T24808   C1721487         NaN          F
# 4812        T24814   C1439436         NaN          M
# 4927        T24929   C6428346         NaN          M
# 4973        T24975   C3689828         NaN          M
#
#                         CustLocation  CustAccountBalance TransactionDate  \
# 170                          PATIALA            32598.06         23/9/16
# 345                          LUCKNOW            38823.95         23/9/16
# 351                           MOHALI           222501.99         23/9/16
# 470                        BANGALORE              174.81         23/9/16
# 617                            DELHI           296460.54         23/9/16
# 1131                           DELHI            77408.30         23/9/16
# 1220                         PATIALA            32598.06         23/9/16
# 1291                          MUMBAI            84098.47         23/9/16
# 1626                         KOLKATA           643719.49         23/9/16
# 1733                         PATIALA            32598.06         23/9/16
# 1801                        LUDHIANA            49339.70         23/9/16
# 2420                       NEW DELHI           152491.04         23/9/16
# 2516                       BANGALORE            20314.27         23/9/16
# 2583                         PATIALA            32598.06         23/9/16
# 2945                          MUMBAI           144797.84         22/9/16
# 3054                          MUMBAI             6862.77         23/9/16
# 3232                          MUMBAI             8398.19         23/9/16
# 3395  OPP CALIFORNIA PIZZA BANGALORE            61133.49         27/9/16
# 3608                           SURAT            12968.80         27/9/16
# 3811                          BHOPAL            30014.33         27/9/16
# 3832               REIS MAGOS BARDEZ             2630.67         26/9/16
# 3937                           DELHI            77408.30         22/9/16
# 3976                     CHEMBUR (E)             6227.11         27/9/16
# 4072                           DELHI            36561.38         26/9/16
# 4536                        SAHNEWAL              724.48         26/9/16
# 4602                       NEW DELHI            12530.13         26/9/16
# 4636                         LUCKNOW           170751.71         27/9/16
# 4806                         KOLKATA           643719.49         27/9/16
# 4812                         GANGTOK           193952.81         22/9/16
# 4927                        SAHNEWAL              724.48         26/9/16
# 4973                          KANPUR           295871.53         26/9/16
#
#       TransactionTime  TransactionAmount (INR)
# 170            194559                   612.65
# 345            193308                  1265.00
# 351            211043                  1633.00
# 470            203649                   656.20
# 617            195319                  1000.00
# 1131           195655                  1000.00
# 1220           200903                   612.65
# 1291           192120                 10454.00
# 1626           190520                  2905.00
# 1733           193152                   612.65
# 1801           195000                  1630.00
# 2420           114757                  1000.00
# 2516           120927                   800.00
# 2583           193645                   612.65
# 2945            23522                  2660.00
# 3054           140029                  3093.00
# 3232           193851                  4521.00
# 3395           162617                   165.00
# 3608           154500                   500.00
# 3811           171744                  1200.00
# 3832           171413                   500.00
# 3937           130527                   949.00
# 3976           161819                   230.00
# 4072           181532                   115.23
# 4536           141609                 12000.00
# 4602           154959                  5384.00
# 4636           164816                 12750.00
# 4806           172143                  1000.00
# 4812           122943                   390.00
# 4927           160136                 15000.00
# 4973           163648                  2100.00

# %%
df_len = len(df.values)
df = df.dropna()
df_len_cleaned = len(df.values)
data_removed = df_len - df_len_cleaned
print('Initial length : ',df_len, '\nLength after cleaning : ',df_len_cleaned, ' (',str(data_removed), ' rows removed )')
# Out:
# Initial length :  5000
# Length after cleaning :  4960  ( 40  rows removed )

# %%
# Check existing missing values
df.isna().sum()
# Out:
# TransactionID              0
# CustomerID                 0
# CustomerDOB                0
# CustGender                 0
# CustLocation               0
# CustAccountBalance         0
# TransactionDate            0
# TransactionTime            0
# TransactionAmount (INR)    0
# dtype: int64

# %%
df
# Out:
#      TransactionID CustomerID CustomerDOB CustGender CustLocation  \
# 0           T20002   C3511547     18/4/98          F        DELHI
# 1           T20003   C1340791     29/9/87          F     KOTTAYAM
# 2           T20004   C4726327    15/10/91          F         TONK
# 3           T20005   C3612791     17/4/72          F       MUMBAI
# 4           T20006   C3935459    12/11/86          F        NOIDA
# ...            ...        ...         ...        ...          ...
# 4995        T24997   C4820781    21/11/80          M    BANGALORE
# 4996        T24998   C7515790     22/2/85          M      GURGAON
# 4997        T24999   C8218573      2/5/91          F       RAIGAD
# 4998        T25000   C1531449     29/4/90          F      LUCKNOW
# 4999        T25001   C4435213     12/5/70          M    ERNAKULAM
#
#       CustAccountBalance TransactionDate  TransactionTime  \
# 0                7267.76         23/9/16           193515
# 1                4971.10         23/9/16           193518
# 2                   4.36         23/9/16           193520
# 3               83461.73         23/9/16           192618
# 4                4184.27         23/9/16           194556
# ...                  ...             ...              ...
# 4995            30742.49         27/9/16           161733
# 4996            17687.06         27/9/16           161129
# 4997              600.41         27/9/16           161212
# 4998              673.98         22/9/16            91400
# 4999            19237.72         22/9/16           120514
#
#       TransactionAmount (INR)
# 0                      100.00
# 1                      251.00
# 2                      200.00
# 3                      975.04
# 4                       58.00
# ...                       ...
# 4995                   214.00
# 4996                   125.00
# 4997                   353.00
# 4998                    16.72
# 4999                  1000.00
#
# [4960 rows x 9 columns]

# %%
df['CustomerDOB'].value_counts()
# Out:
# 1/1/1800    308
# 1/1/89        9
# 1/1/91        7
# 7/2/80        7
# 1/1/88        6
#            ...
# 31/8/93       1
# 12/7/74       1
# 24/6/83       1
# 17/11/94      1
# 12/5/70       1
# Name: CustomerDOB, Length: 3343, dtype: int64

# %%
df = df[df['CustomerDOB'] != '1/1/1800']
df['CustomerDOB'].value_counts()
# Out:
# 1/1/89     9
# 1/1/91     7
# 7/2/80     7
# 1/1/88     6
# 1/1/92     6
#           ..
# 15/8/65    1
# 2/4/70     1
# 18/3/86    1
# 2/8/86     1
# 12/5/70    1
# Name: CustomerDOB, Length: 3342, dtype: int64

# %%
len(df.values)
# Out:
# 4652

# %%
# Fix date formatting 
df['CustomerDOB'] = pd.to_datetime(df['CustomerDOB'])
df['TransactionDate'] = pd.to_datetime(df['TransactionDate'])
df
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_28820\2814770148.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CustomerDOB'] = pd.to_datetime(df['CustomerDOB'])
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_28820\2814770148.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TransactionDate'] = pd.to_datetime(df['TransactionDate'])
#      TransactionID CustomerID CustomerDOB CustGender CustLocation  \
# 0           T20002   C3511547  1998-04-18          F        DELHI
# 1           T20003   C1340791  1987-09-29          F     KOTTAYAM
# 2           T20004   C4726327  1991-10-15          F         TONK
# 3           T20005   C3612791  1972-04-17          F       MUMBAI
# 4           T20006   C3935459  1986-12-11          F        NOIDA
# ...            ...        ...         ...        ...          ...
# 4995        T24997   C4820781  1980-11-21          M    BANGALORE
# 4996        T24998   C7515790  1985-02-22          M      GURGAON
# 4997        T24999   C8218573  1991-02-05          F       RAIGAD
# 4998        T25000   C1531449  1990-04-29          F      LUCKNOW
# 4999        T25001   C4435213  2070-12-05          M    ERNAKULAM
#
#       CustAccountBalance TransactionDate  TransactionTime  \
# 0                7267.76      2016-09-23           193515
# 1                4971.10      2016-09-23           193518
# 2                   4.36      2016-09-23           193520
# 3               83461.73      2016-09-23           192618
# 4                4184.27      2016-09-23           194556
# ...                  ...             ...              ...
# 4995            30742.49      2016-09-27           161733
# 4996            17687.06      2016-09-27           161129
# 4997              600.41      2016-09-27           161212
# 4998              673.98      2016-09-22            91400
# 4999            19237.72      2016-09-22           120514
#
#       TransactionAmount (INR)
# 0                      100.00
# 1                      251.00
# 2                      200.00
# 3                      975.04
# 4                       58.00
# ...                       ...
# 4995                   214.00
# 4996                   125.00
# 4997                   353.00
# 4998                    16.72
# 4999                  1000.00
#
# [4652 rows x 9 columns]

# %%
df['TransactionDate'].value_counts()
# Out:
# 2016-09-23    2923
# 2016-09-26     780
# 2016-09-27     649
# 2016-09-22     300
# Name: TransactionDate, dtype: int64

# %%
# Visualizing Transaction Amount & Transaction Date correlation
sns.scatterplot(y = df['TransactionAmount (INR)'], x = df['TransactionDate'], hue = df['CustGender'])
plt.xlabel('Transaction Date')
plt.ylabel('Transaction Amount (INR)')
plt.show()

# %%
# Visualizing Transaction Amount & Transaction Date correlation
sns.catplot(data = df, y = 'TransactionAmount (INR)', x = 'TransactionDate', hue = 'CustGender')
plt.xlabel('Transaction Date')
plt.ylabel('Transaction Amount (INR)')
plt.show()

# %%
# Finding correlation between data columns
sns.heatmap(df.corr(),annot=True,cmap='viridis',vmin=-1,vmax=1)
plt.show()

# %%
# Highest transaction amount based on location
# df['CustLocation'].value_counts(ascending = False)
df_cust_location = df.groupby('CustLocation')['TransactionAmount (INR)'].sum().sort_values(ascending = False)[:10]
df_cust_location.plot(kind= 'bar', color = ['r','g','b'])
plt.ylabel('Total Customer Transaction')
plt.show()

# %%
df_cust_gender_location = df.groupby('CustGender')['TransactionAmount (INR)'].sum().sort_values(ascending = False)
df_cust_gender_location.plot(kind= 'bar', color = ['r','g'])
plt.ylabel('Total Customer Transaction')
plt.xticks(rotation = 360)
plt.show()

# %%
# Highest Customer Account Balance based on Location
df_cust_bal = df.groupby('CustLocation')['CustAccountBalance'].sum().sort_values(ascending = False)[:10]
df_cust_bal.plot(kind= 'bar', color = ['r','g','b'])
plt.ylabel('Total Customer Account Balance')
plt.show()

# %%
# Highest Customer Account Balance based on Location
df_cust_gender_bal = df.groupby('CustGender')['CustAccountBalance'].sum().sort_values(ascending = False)
# df_cust_gender_bal
df_cust_gender_bal.plot(kind= 'bar', color = ['g','b'])
plt.ylabel('Total Customer Account Balance')
plt.xticks(rotation = 360)
plt.show()
